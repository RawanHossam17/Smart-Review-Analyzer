# %%
import numpy as np

from scipy.sparse import load_npz

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
# Load TF-IDF matrices
X_train_tfidf = load_npz("../outputs/X_train_tfidf.npz")

X_test_tfidf = load_npz("../outputs/X_test_tfidf.npz")

# Load labels
y_train = np.load("../outputs/y_train.npy")

y_test = np.load("../outputs/y_test.npy")

# %% [markdown]
# # Naive Bayes

# %%
# Train Naive Bayes model
nb_model = MultinomialNB(alpha=1)

nb_model.fit(X_train_tfidf, y_train)

# Predictions
y_pred_nb = nb_model.predict(X_test_tfidf)

# Accuracy
print("Naive Bayes Accuracy:",
      accuracy_score(y_test, y_pred_nb))
# Out:
# Naive Bayes Accuracy: 0.8616

# %%
# Save Naive Bayes predictions
np.save("../outputs/y_pred_nb.npy", y_pred_nb)

# %%
# Save Naive Bayes model
joblib.dump(
    nb_model,
    '../outputs/nb_model.pkl'
)
# Out:
# ['../outputs/nb_model.pkl']

# %% [markdown]
# # Logistic Regression

# %%
# Train Logistic Regression model
log_model = LogisticRegression(penalty='l2')

log_model.fit(X_train_tfidf, y_train)

# Predictions
y_pred_log = log_model.predict(X_test_tfidf)

# Accuracy
print("Logistic Regression Accuracy:",
      accuracy_score(y_test, y_pred_log))
# Out:
# Logistic Regression Accuracy: 0.8944

# %%
# Save Logistic Regression predictions
np.save("../outputs/y_pred_log.npy", y_pred_log)

# %%
import joblib

# Save Logistic Regression model
joblib.dump(
    log_model,
    '../outputs/logistic_model.pkl'
)
# Out:
# ['../outputs/logistic_model.pkl']
